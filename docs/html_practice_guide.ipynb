# %% [markdown]
# # HTML Code Practice
#
# This notebook documents the HTML practice repository.
#
# The goal of this repository is to learn and practice HTML fundamentals.

# %% [markdown]
# ## Topics Covered
#
# - HTML structure
# - Headings
# - Paragraphs
# - Lists
# - Links
# - Images
# - Forms

# %%
html_example = """
<!DOCTYPE html>
<html>
<head>
<title>Example Page</title>
</head>

<body>

<h1>Hello World</h1>
<p>This is a basic HTML example.</p>

</body>
</html>
"""

print(html_example)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Page</title>
# </head>
#
# <body>
#
# <h1>Hello World</h1>
# <p>This is a basic HTML example.</p>
#
# </body>
# </html>
